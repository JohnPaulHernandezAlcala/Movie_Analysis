# %% [markdown]
# ## Final Project Submission
#
# * Please fill out:
# * John Paul Hernandez Alcala
# * Part Time
# * Scheduled project review date/time:
# * Instructor name: Eli
# * Blog post URL:

# %% [markdown]
# ### Libraries used

# %%
#!pip install omdb #if not installed already

import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import omdb
import itertools as it
from datetime import datetime, date
from matplotlib.patches import Rectangle
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Bringing in OMDb and R.O.I. Data to Merge into One Dataset

# %% [markdown]
# First we are going to bring in the movie budget dataframe we obtained from [MovieBudgetData.ipynb](./MovieBudgetData.ipynb) to join the data obtained from OMDb API in [OMDb_Data.ipynb](OMDb_Data.ipynb).

# %% [markdown]
# ### Movie Budget Data: R.O.I.

# %%
#Run jupyter notebook folder to define necessary variables
#%% capture 
# %run ./MovieBudgetAnalysis.ipynb #capture output of file ran.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5126 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5126 non-null   int64
#  1   release_date       5126 non-null   object
#  2   movie              5126 non-null   object
#  3   production_budget  5126 non-null   int64
#  4   domestic_gross     5126 non-null   int64
#  5   worldwide_gross    5126 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 280.3+ KB
# C:\Users\johnh\Anaconda3\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     677
#     678         with _wrap_text(self) as textobj:
# --> 679             bbox, info, descent = textobj._get_layout(renderer)
#     680             trans = textobj.get_transform()
#     681
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     270         of a rotated text when necessary.
#     271         """
# --> 272         key = self.get_prop_tup(renderer=renderer)
#     273         if key in self._cached:
#     274             return self._cached[key]
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in get_prop_tup(self, renderer)
#     838         need to know if the text has changed.
#     839         """
# --> 840         x, y = self.get_unitless_position()
#     841         renderer = renderer or self._renderer
#     842         return (x, y, self.get_text(), self._color,
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in get_unitless_position(self)
#     820         # This will get the position with all unit information stripped away.
#     821         # This is here for convenience since it is done in several locations.
# --> 822         x = float(self.convert_xunits(self._x))
#     823         y = float(self.convert_yunits(self._y))
#     824         return x, y
#
# TypeError: only size-1 arrays can be converted to Python scalars
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5126 entries, 0 to 5125
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   movie                5126 non-null   object
#  1   year                 5126 non-null   object
#  2   Worldwide R.O.I.(%)  5126 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 120.3+ KB
# Stored 'dfROI' (DataFrame)

# %%
# %store -r dfROI
dfROI.head() #retrieve stored variable and output head
# Out:
#                                          movie  year  Worldwide R.O.I.(%)
# 0                                       Avatar  2009           553.257713
# 1  Pirates of the Caribbean: On Stranger Tides  2011           154.667286
# 2                                 Dark Phoenix  2019           -57.210757
# 3                      Avengers: Age of Ultron  2015           324.384139
# 4            Star Wars Ep. VIII: The Last Jedi  2017           315.369636

# %%
dfROI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5126 entries, 0 to 5125
# Data columns (total 3 columns):
# movie                  5126 non-null object
# year                   5126 non-null object
# Worldwide R.O.I.(%)    5126 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 120.3+ KB

# %% [markdown]
# ### OMDb Data

# %%
df0 = pd.read_csv('./ImprovedReadyOMDbAPIData', index_col=0) #read in data into dataframe

# %%
dfOMDb = df0.reset_index(drop=True) #reset index

# %%
dfOMDb.tail(10)
# Out:
#                                            Title  Year      Rated  \
# 4933                      Romance and Cigarettes  1999          R
# 4934       The Work and the Glory: American Zion  2017  Not Rated
# 4935  Dolphins and Whales Tribes of the Ocean 3D  2000  Not Rated
# 4936               Pat Garrett and Billy the Kid  1973          R
# 4937                                Ira and Abby  2018        NaN
# 4938                    Travellers and Magicians  1992        NaN
# 4939                   Celeste and Jesse Forever  2018      TV-14
# 4940                          Lovely and Amazing  2012        NaN
# 4941     Peace, Propaganda and the Promised Land  2004        NaN
# 4942               Smiling Fish and Goat on Fire  1999          R
#
#          Released  Runtime                      Genre  \
# 4933  14 Apr 1999   84 min             Drama, Romance
# 4934  08 Sep 2017   89 min                Documentary
# 4935  14 Apr 2000   39 min         Documentary, Short
# 4936  23 May 1973  122 min  Biography, Drama, Western
# 4937  16 Mar 2018  139 min   Crime, Mystery, Thriller
# 4938  01 Feb 1994   90 min                      Drama
# 4939  06 Feb 2019  105 min               Drama, Music
# 4940  30 Mar 2012  139 min                    Romance
# 4941          NaN   80 min                Documentary
# 4942  10 Mar 2000   90 min            Comedy, Romance
#
#                                         Director  \
# 4933                          Catherine Breillat
# 4934  Jairus McLeary, Gethin Aldous(co-director)
# 4935                           Greg MacGillivray
# 4936                               Sam Peckinpah
# 4937                                  Saiju S.S.
# 4938                               Bahram Beizai
# 4939                               Ben Hackworth
# 4940                                     Jaya B.
# 4941              Sut Jhally, Bathsheba Ratzkoff
# 4942                                Kevin Jordan
#
#                                                  Writer  \
# 4933         Catherine Breillat (scenario and dialogue)
# 4934                                                NaN
# 4935                         Tim Cahill, Stephen Judson
# 4936                                     Rudy Wurlitzer
# 4937                                        Naveen John
# 4938                                      Bahram Beizai
# 4939                         Bille Brown, Ben Hackworth
# 4940  Jaya B. (story & screenplay), Shyam Manohar (d...
# 4941                     Sut Jhally, Bathsheba Ratzkoff
# 4942  Kevin Jordan (story), Derick Martini (screenpl...
#
#                                                  Actors  \
# 4933  Caroline Ducey, Sagamore Stévenin, François Be...
# 4934  Eldra 'Vegas' III Jackson, Alvin 'Bud' Wheeler...
# 4935  Pierce Brosnan, Alejandro Acevedo-Gutiérrez, D...
# 4936  James Coburn, Kris Kristofferson, Richard Jaec...
# 4937  Unni Mukundan, Gokul Suresh, Shankar Ramakrish...
# 4938  Mozhdeh Shamsai, Homa Rusta, Jamileh Sheikhi, ...
# 4939  Radha Mitchell, Thomas Cocquerel, Nadine Garne...
# 4940  Aadi, Shanvi Srivastava, Rajendra Prasad, Chin...
# 4941  Seth Ackerman, Stav Adivi, Arik Ascherman, Han...
# 4942  Derick Martini, Amy Hathaway, Steven Martini, ...
#
#                                                    Plot  ...  \
# 4933  Frustrated by the lack of intimacy in her rela...  ...
# 4934  Set inside a single room in Folsom Prison, thr...  ...
# 4935  Experience how dolphins live and play, and unr...  ...
# 4936  Pat Garrett is hired as a lawman on behalf of ...  ...
# 4937  Aryan is like every other lover, who finds the...  ...
# 4938  A young woman's wedding becomes a ritual of mo...  ...
# 4939  Celeste is a love story set in the tropical sp...  ...
# 4940                                                NaN  ...
# 4941  This video shows how the foreign policy intere...  ...
# 4942  Two brothers share a house in the Fairfax dist...  ...
#
#                                                  Poster  \
# 4933  https://m.media-amazon.com/images/M/MV5BNjY4ND...
# 4934  https://m.media-amazon.com/images/M/MV5BMjI2Zm...
# 4935  https://m.media-amazon.com/images/M/MV5BMTA0Nz...
# 4936  https://m.media-amazon.com/images/M/MV5BNDU3ND...
# 4937  https://m.media-amazon.com/images/M/MV5BNjVjNm...
# 4938  https://m.media-amazon.com/images/M/MV5BMTU0Mj...
# 4939  https://m.media-amazon.com/images/M/MV5BYTQyMz...
# 4940  https://m.media-amazon.com/images/M/MV5BN2Y4Nm...
# 4941  https://m.media-amazon.com/images/M/MV5BMjA4OT...
# 4942  https://m.media-amazon.com/images/M/MV5BMTQwOT...
#
#                                                 Ratings Metascore imdbRating  \
# 4933  [{'Source': 'Internet Movie Database', 'Value'...      49.0        5.3
# 4934  [{'Source': 'Internet Movie Database', 'Value'...      84.0        7.8
# 4935  [{'Source': 'Internet Movie Database', 'Value'...       NaN        7.3
# 4936  [{'Source': 'Internet Movie Database', 'Value'...      53.0        7.3
# 4937  [{'Source': 'Internet Movie Database', 'Value'...       NaN        6.9
# 4938  [{'Source': 'Internet Movie Database', 'Value'...       NaN        7.4
# 4939  [{'Source': 'Internet Movie Database', 'Value'...       NaN        5.5
# 4940  [{'Source': 'Internet Movie Database', 'Value'...       NaN        5.4
# 4941  [{'Source': 'Internet Movie Database', 'Value'...      57.0        8.2
# 4942  [{'Source': 'Internet Movie Database', 'Value'...      44.0        7.7
#
#      imdbVotes     imdbID   Type          DVD   BoxOffice  \
# 4933    10,112  tt0194314  movie  08 Feb 2000  $1,585,642
# 4934     2,104  tt5836866  movie          NaN      $5,853
# 4935       459  tt0263278  movie  30 Nov 2016         NaN
# 4936    18,289  tt0070518  movie  01 Jan 2008         NaN
# 4937       725  tt7601308  movie          NaN         NaN
# 4938       906  tt0104919  movie          NaN         NaN
# 4939       159  tt5705306  movie  29 May 2019         NaN
# 4940       155  tt2334727  movie          NaN         NaN
# 4941       531  tt0428959  movie          NaN      $4,930
# 4942     2,663  tt0162348  movie  21 Aug 2001    $278,492
#
#                                              Production
# 4933                                                NaN
# 4934                                 Blanket Fort Media
# 4935                                                NaN
# 4936                                Metro Goldwyn Mayer
# 4937                                                NaN
# 4938                                                NaN
# 4939                                      Unicorn Films
# 4940                                                NaN
# 4941                                                NaN
# 4942  Parabellum Productions, Stratosphere Entertain...
#
# [10 rows x 23 columns]

# %%
dfOMDb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4943 entries, 0 to 4942
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       4943 non-null   object
#  1   Year        4943 non-null   object
#  2   Rated       4673 non-null   object
#  3   Released    4871 non-null   object
#  4   Runtime     4888 non-null   object
#  5   Genre       4932 non-null   object
#  6   Director    4856 non-null   object
#  7   Writer      4769 non-null   object
#  8   Actors      4907 non-null   object
#  9   Plot        4820 non-null   object
#  10  Language    4927 non-null   object
#  11  Country     4940 non-null   object
#  12  Awards      4209 non-null   object
#  13  Poster      4809 non-null   object
#  14  Ratings     4849 non-null   object
#  15  Metascore   4288 non-null   float64
#  16  imdbRating  4847 non-null   float64
#  17  imdbVotes   4847 non-null   object
#  18  imdbID      4943 non-null   object
#  19  Type        4943 non-null   object
#  20  DVD         4508 non-null   object
#  21  BoxOffice   4479 non-null   object
#  22  Production  4389 non-null   object
# dtypes: float64(2), object(21)
# memory usage: 888.3+ KB

# %% [markdown]
# Next, we need to rename the 'movie' column in dfROI to 'title', so we can merge our dataframes.

# %%
dfROI = dfROI.rename(columns = {'movie':'Title', 'year': 'Year'}) #here I rename to make sure the column names match
dfROI
# Out:
#                                             Title  Year  Worldwide R.O.I.(%)
# 0                                          Avatar  2009           553.257713
# 1     Pirates of the Caribbean: On Stranger Tides  2011           154.667286
# 2                                    Dark Phoenix  2019           -57.210757
# 3                         Avengers: Age of Ultron  2015           324.384139
# 4               Star Wars Ep. VIII: The Last Jedi  2017           315.369636
# ...                                           ...   ...                  ...
# 5121                                       Cavite  2006           923.485714
# 5122                              The Mongol King  2004           -87.142857
# 5123                                    Following  1999          3908.250000
# 5124                Return to the Land of Wonders  2005           -73.240000
# 5125                            My Date With Drew  2005         16358.272727
#
# [5126 rows x 3 columns]

# %%
dfROI.keys() #check if title columns have changed
# Out:
# Index(['Title', 'Year', 'Worldwide R.O.I.(%)'], dtype='object')

# %%
dfOMDb.keys()
# Out:
# Index(['Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre', 'Director',
#        'Writer', 'Actors', 'Plot', 'Language', 'Country', 'Awards', 'Poster',
#        'Ratings', 'Metascore', 'imdbRating', 'imdbVotes', 'imdbID', 'Type',
#        'DVD', 'BoxOffice', 'Production'],
#       dtype='object')

# %% [markdown]
# ### Combined Data

# %% [markdown]
# Now, let's merge the two dataframes.

# %%
dfOMDb.loc[:, ['Title', 'Year']] #selects only these two columns
# Out:
#                                             Title  Year
# 0                                          Avatar  2009
# 1     Pirates of the Caribbean: On Stranger Tides  2011
# 2                                    Dark Phoenix  2019
# 3                         Avengers: Age of Ultron  2015
# 4                          Avengers: Infinity War  2018
# ...                                           ...   ...
# 4938                     Travellers and Magicians  1992
# 4939                    Celeste and Jesse Forever  2018
# 4940                           Lovely and Amazing  2012
# 4941      Peace, Propaganda and the Promised Land  2004
# 4942                Smiling Fish and Goat on Fire  1999
#
# [4943 rows x 2 columns]

# %%
dfOMDb[dfOMDb.duplicated(subset=['Title'])] #selects the title column
# Out:
#                             Title  Year  Rated     Released  Runtime  \
# 255                      Godzilla  1998  PG-13  20 May 1998  139 min
# 375                    Robin Hood  2018  PG-13  21 Nov 2018  116 min
# 445                Fantastic Four  2005  PG-13  08 Jul 2005  106 min
# 501                     The Mummy  1999  PG-13  07 May 1999  124 min
# 653                      Hercules  1997      G  27 Jun 1997   93 min
# ...                           ...   ...    ...          ...      ...
# 4464                  Left Behind  2014  PG-13  03 Oct 2014  110 min
# 4687                  The Gambler  2014      R  25 Dec 2014  111 min
# 4743             Dawn of the Dead  2004      R  19 Mar 2004  101 min
# 4874  The Texas Chainsaw Massacre  2003      R  17 Oct 2003   98 min
# 4883                   The Signal  2014  PG-13  10 Jul 2014   97 min
#
#                                                   Genre  \
# 255                            Action, Sci-Fi, Thriller
# 375                  Action, Adventure, Drama, Thriller
# 445                  Action, Adventure, Fantasy, Sci-Fi
# 501                          Action, Adventure, Fantasy
# 653   Animation, Adventure, Comedy, Family, Fantasy,...
# ...                                                 ...
# 4464                  Action, Fantasy, Sci-Fi, Thriller
# 4687                             Crime, Drama, Thriller
# 4743                                     Action, Horror
# 4874                                      Crime, Horror
# 4883                   Drama, Mystery, Sci-Fi, Thriller
#
#                        Director  \
# 255             Roland Emmerich
# 375               Otto Bathurst
# 445                   Tim Story
# 501             Stephen Sommers
# 653   Ron Clements, John Musker
# ...                         ...
# 4464              Vic Armstrong
# 4687               Rupert Wyatt
# 4743                Zack Snyder
# 4874              Marcus Nispel
# 4883             William Eubank
#
#                                                  Writer  \
# 255   Dean Devlin (screenplay), Roland Emmerich (scr...
# 375   Ben Chandler (screenplay by), David James Kell...
# 445   Mark Frost, Michael France, Stan Lee (Marvel c...
# 501   Stephen Sommers (screen story), Lloyd Fonviell...
# 653   Ron Clements (animation screenplay by), John M...
# ...                                                 ...
# 4464  Jerry B. Jenkins (based on novel), Tim LaHaye ...
# 4687         William Monahan (screenplay), James Toback
# 4743          George A. Romero, James Gunn (screenplay)
# 4874  Kim Henkel, Tobe Hooper, Scott Kosar (screenplay)
# 4883     Carlyle Eubank, William Eubank, David Frigerio
#
#                                                  Actors  \
# 255   Matthew Broderick, Jean Reno, Maria Pitillo, H...
# 375   Taron Egerton, Jamie Foxx, Ben Mendelsohn, Eve...
# 445   Ioan Gruffudd, Jessica Alba, Chris Evans, Mich...
# 501   Brendan Fraser, Rachel Weisz, John Hannah, Arn...
# 653   Tate Donovan, Josh Keaton, Roger Bart, Danny D...
# ...                                                 ...
# 4464  Nicolas Cage, Chad Michael Murray, Cassi Thoms...
# 4687  Mark Wahlberg, George Kennedy, Griffin Clevela...
# 4743  Sarah Polley, Ving Rhames, Jake Weber, Mekhi P...
# 4874  Jessica Biel, Jonathan Tucker, Erica Leerhsen,...
# 4883  Patrick Davidson, Brenton Thwaites, Olivia Coo...
#
#                                                    Plot  ...  \
# 255   A giant, reptilian monster surfaces, leaving d...  ...
# 375   A war-hardened Crusader and his Moorish comman...  ...
# 445   A group of astronauts gain superpowers after a...  ...
# 501   At an archaeological dig in the ancient city o...  ...
# 653   The son of Zeus and Hera is stripped of his im...  ...
# ...                                                 ...  ...
# 4464  A small group of survivors are left behind aft...  ...
# 4687  Literature professor and gambler Jim Bennett's...  ...
# 4743  A nurse, a policeman, a young married couple, ...  ...
# 4874  After picking up a traumatized young hitchhike...  ...
# 4883  On a road trip, Nic and two friends are drawn ...  ...
#
#                                                  Poster  \
# 255   https://m.media-amazon.com/images/M/MV5BNjFlOT...
# 375   https://m.media-amazon.com/images/M/MV5BOGQzZD...
# 445   https://m.media-amazon.com/images/M/MV5BNWU1Zj...
# 501   https://m.media-amazon.com/images/M/MV5BOTJiYj...
# 653   https://m.media-amazon.com/images/M/MV5BZDcwYj...
# ...                                                 ...
# 4464  https://m.media-amazon.com/images/M/MV5BMjI4Mj...
# 4687  https://m.media-amazon.com/images/M/MV5BMjA5Mj...
# 4743  https://m.media-amazon.com/images/M/MV5BN2M2Zm...
# 4874  https://m.media-amazon.com/images/M/MV5BZDg2ND...
# 4883  https://m.media-amazon.com/images/M/MV5BNzA4Mj...
#
#                                                 Ratings Metascore imdbRating  \
# 255   [{'Source': 'Internet Movie Database', 'Value'...      32.0        5.4
# 375   [{'Source': 'Internet Movie Database', 'Value'...      32.0        5.3
# 445   [{'Source': 'Internet Movie Database', 'Value'...      40.0        5.7
# 501   [{'Source': 'Internet Movie Database', 'Value'...      48.0        7.0
# 653   [{'Source': 'Internet Movie Database', 'Value'...      74.0        7.3
# ...                                                 ...       ...        ...
# 4464  [{'Source': 'Internet Movie Database', 'Value'...      12.0        3.1
# 4687  [{'Source': 'Internet Movie Database', 'Value'...      55.0        6.1
# 4743  [{'Source': 'Internet Movie Database', 'Value'...      59.0        7.3
# 4874  [{'Source': 'Internet Movie Database', 'Value'...      38.0        6.2
# 4883  [{'Source': 'Internet Movie Database', 'Value'...      54.0        6.1
#
#      imdbVotes     imdbID   Type          DVD     BoxOffice  \
# 255    185,313  tt0120685  movie  16 Apr 2012  $136,314,294
# 375     66,058  tt4532826  movie  05 Feb 2019   $30,824,628
# 445    313,535  tt0120667  movie  26 Jan 2016  $154,696,080
# 501    393,812  tt0120616  movie  01 Nov 2015  $155,385,488
# 653    209,263  tt0119282  movie  13 Dec 2015   $99,112,101
# ...        ...        ...    ...          ...           ...
# 4464    37,541  tt2467046  movie  22 Dec 2014   $14,019,924
# 4687    66,949  tt2039393  movie  24 May 2016   $33,680,992
# 4743   237,096  tt0363547  movie  12 Feb 2014   $59,020,957
# 4874   131,404  tt0324216  movie  24 Jul 2014   $80,571,655
# 4883    63,323  tt2910814  movie  10 Dec 2015      $600,896
#
#                                              Production
# 255   Fried Films, Independent Pictures, TriStar Pic...
# 375   Summit Entertainment, Safehouse Pictures, Appi...
# 445   1492 Pictures, 20th Century Fox, Marvel Enterp...
# 501                Universal Pictures, Alphaville Films
# 653                                Walt Disney Pictures
# ...                                                 ...
# 4464                          Stoney Lake Entertainment
# 4687    Chartoff Winkler, Leverage, Closest to the Hole
# 4743  Strike Entertainment, New Amsterdam Entertainm...
# 4874  Next Entertainment Inc., New Line Cinema, Plat...
# 4883                         Low Spark Films, Automatik
#
# [74 rows x 23 columns]

# %%
dfOMDb_no_duplicates = dfOMDb.drop_duplicates(subset=['Title'])
dfOMDb_no_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4869 entries, 0 to 4942
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       4869 non-null   object
#  1   Year        4869 non-null   object
#  2   Rated       4600 non-null   object
#  3   Released    4797 non-null   object
#  4   Runtime     4814 non-null   object
#  5   Genre       4858 non-null   object
#  6   Director    4782 non-null   object
#  7   Writer      4696 non-null   object
#  8   Actors      4833 non-null   object
#  9   Plot        4747 non-null   object
#  10  Language    4853 non-null   object
#  11  Country     4866 non-null   object
#  12  Awards      4145 non-null   object
#  13  Poster      4735 non-null   object
#  14  Ratings     4775 non-null   object
#  15  Metascore   4225 non-null   float64
#  16  imdbRating  4773 non-null   float64
#  17  imdbVotes   4773 non-null   object
#  18  imdbID      4869 non-null   object
#  19  Type        4869 non-null   object
#  20  DVD         4442 non-null   object
#  21  BoxOffice   4417 non-null   object
#  22  Production  4322 non-null   object
# dtypes: float64(2), object(21)
# memory usage: 912.9+ KB

# %%
dfROI.loc[:, ['Title', 'Year']]
# Out:
#                                             Title  Year
# 0                                          Avatar  2009
# 1     Pirates of the Caribbean: On Stranger Tides  2011
# 2                                    Dark Phoenix  2019
# 3                         Avengers: Age of Ultron  2015
# 4               Star Wars Ep. VIII: The Last Jedi  2017
# ...                                           ...   ...
# 5121                                       Cavite  2006
# 5122                              The Mongol King  2004
# 5123                                    Following  1999
# 5124                Return to the Land of Wonders  2005
# 5125                            My Date With Drew  2005
#
# [5126 rows x 2 columns]

# %%
dfROI[dfROI.duplicated(subset=['Title'])]
# Out:
#                            Title  Year  Worldwide R.O.I.(%)
# 264                     Godzilla  1998           200.800000
# 394                   Robin Hood  2018           -14.396524
# 468               Fantastic Four  2005           280.723143
# 525                    The Mummy  1999           420.481860
# 681                     Hercules  1997           258.142857
# ...                          ...   ...                  ...
# 5060                  Cat People  1942          5870.149254
# 5062    Night of the Living Dead  1968         26292.161404
# 5063       The Birth of a Nation  1915          9900.000000
# 5077  The Last House on the Left  1972          3463.218391
# 5089                  The Signal  2008           712.598000
#
# [74 rows x 3 columns]

# %%
dfROI_no_duplicates = dfROI.drop_duplicates(subset=['Title'])
dfROI_no_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5052 entries, 0 to 5125
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                5052 non-null   object
#  1   Year                 5052 non-null   object
#  2   Worldwide R.O.I.(%)  5052 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 157.9+ KB

# %%
dfROI_no_duplicates[dfROI_no_duplicates.duplicated(subset=['Title'])]
# Out:
# Empty DataFrame
# Columns: [Title, Year, Worldwide R.O.I.(%)]
# Index: []

# %%
dfCombined = dfOMDb_no_duplicates.merge(dfROI_no_duplicates, how='left', on='Title') #we are going to combine the two dataframes into one.

# %%
dfCombined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4869 entries, 0 to 4868
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                4869 non-null   object
#  1   Year_x               4869 non-null   object
#  2   Rated                4600 non-null   object
#  3   Released             4797 non-null   object
#  4   Runtime              4814 non-null   object
#  5   Genre                4858 non-null   object
#  6   Director             4782 non-null   object
#  7   Writer               4696 non-null   object
#  8   Actors               4833 non-null   object
#  9   Plot                 4747 non-null   object
#  10  Language             4853 non-null   object
#  11  Country              4866 non-null   object
#  12  Awards               4145 non-null   object
#  13  Poster               4735 non-null   object
#  14  Ratings              4775 non-null   object
#  15  Metascore            4225 non-null   float64
#  16  imdbRating           4773 non-null   float64
#  17  imdbVotes            4773 non-null   object
#  18  imdbID               4869 non-null   object
#  19  Type                 4869 non-null   object
#  20  DVD                  4442 non-null   object
#  21  BoxOffice            4417 non-null   object
#  22  Production           4322 non-null   object
#  23  Year_y               4869 non-null   object
#  24  Worldwide R.O.I.(%)  4869 non-null   float64
# dtypes: float64(3), object(22)
# memory usage: 989.0+ KB

# %%
dfCombined
# Out:
#                                             Title Year_x  Rated     Released  \
# 0                                          Avatar   2009  PG-13  18 Dec 2009
# 1     Pirates of the Caribbean: On Stranger Tides   2011  PG-13  20 May 2011
# 2                                    Dark Phoenix   2019  PG-13  07 Jun 2019
# 3                         Avengers: Age of Ultron   2015  PG-13  01 May 2015
# 4                          Avengers: Infinity War   2018  PG-13  27 Apr 2018
# ...                                           ...    ...    ...          ...
# 4864                     Travellers and Magicians   1992    NaN  01 Feb 1994
# 4865                    Celeste and Jesse Forever   2018  TV-14  06 Feb 2019
# 4866                           Lovely and Amazing   2012    NaN  30 Mar 2012
# 4867      Peace, Propaganda and the Promised Land   2004    NaN          NaN
# 4868                Smiling Fish and Goat on Fire   1999      R  10 Mar 2000
#
#       Runtime                               Genre  \
# 0     162 min  Action, Adventure, Fantasy, Sci-Fi
# 1     136 min          Action, Adventure, Fantasy
# 2     113 min           Action, Adventure, Sci-Fi
# 3     141 min           Action, Adventure, Sci-Fi
# 4     149 min           Action, Adventure, Sci-Fi
# ...       ...                                 ...
# 4864   90 min                               Drama
# 4865  105 min                        Drama, Music
# 4866  139 min                             Romance
# 4867   80 min                         Documentary
# 4868   90 min                     Comedy, Romance
#
#                             Director  \
# 0                      James Cameron
# 1                       Rob Marshall
# 2                      Simon Kinberg
# 3                        Joss Whedon
# 4           Anthony Russo, Joe Russo
# ...                              ...
# 4864                   Bahram Beizai
# 4865                   Ben Hackworth
# 4866                         Jaya B.
# 4867  Sut Jhally, Bathsheba Ratzkoff
# 4868                    Kevin Jordan
#
#                                                  Writer  \
# 0                                         James Cameron
# 1     Ted Elliott (screenplay), Terry Rossio (screen...
# 2                                         Simon Kinberg
# 3     Joss Whedon, Stan Lee (based on the Marvel com...
# 4     Christopher Markus (screenplay by), Stephen Mc...
# ...                                                 ...
# 4864                                      Bahram Beizai
# 4865                         Bille Brown, Ben Hackworth
# 4866  Jaya B. (story & screenplay), Shyam Manohar (d...
# 4867                     Sut Jhally, Bathsheba Ratzkoff
# 4868  Kevin Jordan (story), Derick Martini (screenpl...
#
#                                                  Actors  \
# 0     Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1     Johnny Depp, Penélope Cruz, Geoffrey Rush, Ian...
# 2     James McAvoy, Michael Fassbender, Jennifer Law...
# 3     Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 4     Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# ...                                                 ...
# 4864  Mozhdeh Shamsai, Homa Rusta, Jamileh Sheikhi, ...
# 4865  Radha Mitchell, Thomas Cocquerel, Nadine Garne...
# 4866  Aadi, Shanvi Srivastava, Rajendra Prasad, Chin...
# 4867  Seth Ackerman, Stav Adivi, Arik Ascherman, Han...
# 4868  Derick Martini, Amy Hathaway, Steven Martini, ...
#
#                                                    Plot  ... Metascore  \
# 0     A paraplegic Marine dispatched to the moon Pan...  ...      83.0
# 1     Jack Sparrow and Barbossa embark on a quest to...  ...      45.0
# 2     Jean Grey begins to develop incredible powers ...  ...      43.0
# 3     When Tony Stark and Bruce Banner try to jump-s...  ...      66.0
# 4     The Avengers and their allies must be willing ...  ...      68.0
# ...                                                 ...  ...       ...
# 4864  A young woman's wedding becomes a ritual of mo...  ...       NaN
# 4865  Celeste is a love story set in the tropical sp...  ...       NaN
# 4866                                                NaN  ...       NaN
# 4867  This video shows how the foreign policy intere...  ...      57.0
# 4868  Two brothers share a house in the Fairfax dist...  ...      44.0
#
#      imdbRating  imdbVotes     imdbID   Type          DVD     BoxOffice  \
# 0           7.8  1,129,705  tt0499549  movie  10 Feb 2016  $760,507,625
# 1           6.6    486,087  tt1298650  movie  07 Aug 2015  $241,071,802
# 2           5.7    159,973  tt6565702  movie  03 Sep 2019   $65,845,974
# 3           7.3    759,059  tt2395427  movie  08 Sep 2015  $459,005,868
# 4           8.4    865,422  tt4154756  movie  31 Jul 2018  $678,815,482
# ...         ...        ...        ...    ...          ...           ...
# 4864        7.4        906  tt0104919  movie          NaN           NaN
# 4865        5.5        159  tt5705306  movie  29 May 2019           NaN
# 4866        5.4        155  tt2334727  movie          NaN           NaN
# 4867        8.2        531  tt0428959  movie          NaN        $4,930
# 4868        7.7      2,663  tt0162348  movie  21 Aug 2001      $278,492
#
#                                              Production Year_y  \
# 0     Dune, Lightstorm Entertainment, Ingenious Film...   2009
# 1         Walt Disney Pictures, Jerry Bruckheimer Films   2011
# 2     TSG Entertainment, 20th Century Fox, Donners&#...   2019
# 3                                        Marvel Studios   2015
# 4                                        Marvel Studios   2018
# ...                                                 ...    ...
# 4864                                                NaN   2005
# 4865                                      Unicorn Films   2012
# 4866                                                NaN   2002
# 4867                                                NaN   2005
# 4868  Parabellum Productions, Stratosphere Entertain...   2000
#
#      Worldwide R.O.I.(%)
# 0             553.257713
# 1             154.667286
# 2             -57.210757
# 3             324.384139
# 4             582.711400
# ...                  ...
# 4864          -26.546611
# 4865          350.915357
# 4866         1745.392800
# 4867          -92.957143
# 4868          593.082500
#
# [4869 rows x 25 columns]

# %% [markdown]
# We notice that the 'title' object number above, 4367, does not match the 'title' object number, 3480. Let's check out what those are, and if we should include them.

# %%
dfOMDb[~dfOMDb.title.isin(dfCombined.title)]
# Out:
#             title       year  rated     released runtime  \
# 692         Agora      2010–    NaN  21 Sep 2010     NaN
# 3048      Quartet      2013–    NaN  01 Oct 2013     NaN
# 3211  The Joneses  2010–2011    NaN  14 Oct 2010  23 min
# 3229  High School  2012–2014  TV-14  11 May 2012  42 min
# 3671   Green Room      2016–    NaN  20 Apr 2016     NaN
# 3720  The Lobster      2016–    NaN          NaN     NaN
# 3834   The Bronze      2016–    NaN  24 Jun 2017  60 min
# 4023     Get Real  1999–2000  TV-14  08 Sep 1999  60 min
# 4081  Cabin Fever      2003–    NaN  01 Jun 2003     NaN
# 4177    Palo Alto  2014–2017    NaN  15 Sep 2014  10 min
# 4194         Hits      2015–    NaN          NaN     NaN
# 4378    Newlyweds      2012–    NaN          NaN  60 min
#
#                                         genre director          writer  \
# 692                                 Game-Show      NaN             NaN
# 3048               Animation, Action, Fantasy      NaN             NaN
# 3211                               Reality-TV      NaN             NaN
# 3229                  Action, Romance, Sci-Fi      NaN             NaN
# 3671                                   Comedy      NaN             NaN
# 3720                                   Comedy      NaN             NaN
# 3834  Crime, Drama, Horror, Mystery, Thriller      NaN             NaN
# 4023                   Comedy, Drama, Romance      NaN  Clyde Phillips
# 4081                               Reality-TV      NaN             NaN
# 4177                            Comedy, Drama      NaN             NaN
# 4194                                    Crime      NaN             NaN
# 4378                              Documentary      NaN             NaN
#
#                                                  actors  \
# 692   Fátima Lopes, Cristina Areia, Helga Brandão, A...
# 3048  Saki Fujita, Misato Fukuen, Yûki Kaji, Miyuki ...
# 3211                         James Blundell, Beau Jones
# 3229  Josh Blaylock, Ellary Porterfield, Johanna Bra...
# 3671  Kevin Michael Shiley, Danielle Montezinos, And...
# 3720  Andrew Joseph Pahlke, Jeff Woodward, Sarah Gibson
# 3834  Joaquín Furriel, Norma Aleandro, Daniel Fanego...
# 4023  Jon Tenney, Debrah Farentino, Eric Christian O...
# 4081                                                NaN
# 4177  Leonardo Amato, Daniela Suran, Edoardo Soldati...
# 4194                                        Dave McCrea
# 4378  Rob Brann, Rochelle Brann, Adonis Gladney, Eri...
#
#                                                    plot  ...  \
# 692                                                 NaN  ...
# 3048  There is a town where humans and demons co-exi...  ...
# 3211  Australian reality TV series that follows the ...  ...
# 3229  In a futuristic world where gaming is the top ...  ...
# 3671  Friends, colleagues and weed come together in ...  ...
# 3720                                                NaN  ...
# 3834  A new history created by the bestseller author...  ...
# 4023  Follow the dysfunctional Green family as the p...  ...
# 4081  Cabin Fever. Take one tall ship, ten contestan...  ...
# 4177  The stories are about teenagers and their expe...  ...
# 4194  When a potentially game-changing deal with a w...  ...
# 4378  Explores the ups and downs of marriage as dive...  ...
#
#                                                  poster  \
# 692                                                 NaN
# 3048  https://m.media-amazon.com/images/M/MV5BOTY3OW...
# 3211  https://m.media-amazon.com/images/M/MV5BNDlkM2...
# 3229  https://m.media-amazon.com/images/M/MV5BOTgxOT...
# 3671  https://m.media-amazon.com/images/M/MV5BZWI2MW...
# 3720                                                NaN
# 3834  https://m.media-amazon.com/images/M/MV5BMDFjMj...
# 4023  https://m.media-amazon.com/images/M/MV5BNGQwNj...
# 4081                                                NaN
# 4177  https://m.media-amazon.com/images/M/MV5BOWJlMz...
# 4194                                                NaN
# 4378  https://m.media-amazon.com/images/M/MV5BMjAxMj...
#
#                                                 ratings metascore imdb_rating  \
# 692                                                 NaN       NaN         NaN
# 3048  [{'source': 'Internet Movie Database', 'value'...       NaN         7.3
# 3211  [{'source': 'Internet Movie Database', 'value'...       NaN         8.5
# 3229  [{'source': 'Internet Movie Database', 'value'...       NaN         7.6
# 3671  [{'source': 'Internet Movie Database', 'value'...       NaN         2.2
# 3720                                                NaN       NaN         NaN
# 3834  [{'source': 'Internet Movie Database', 'value'...       NaN         8.0
# 4023  [{'source': 'Internet Movie Database', 'value'...       NaN         7.1
# 4081  [{'source': 'Internet Movie Database', 'value'...       NaN         3.0
# 4177  [{'source': 'Internet Movie Database', 'value'...       NaN         8.1
# 4194                                                NaN       NaN         NaN
# 4378  [{'source': 'Internet Movie Database', 'value'...       NaN         5.4
#
#      imdb_votes    imdb_id    type  dvd box_office production
# 692         NaN  tt1781967  series  NaN        NaN        NaN
# 3048         47  tt3169640  series  NaN        NaN        NaN
# 3211         43  tt2367359  series  NaN        NaN        NaN
# 3229     12,424  tt2170584  series  NaN        NaN        NaN
# 3671          9  tt4950016  series  NaN        NaN        NaN
# 3720        NaN  tt5438322  series  NaN        NaN        NaN
# 3834        937  tt7048386  series  NaN        NaN        NaN
# 4023        491  tt0212662  series  NaN        NaN        NaN
# 4081         13  tt0498879  series  NaN        NaN        NaN
# 4177         23  tt3400342  series  NaN        NaN        NaN
# 4194        NaN  tt4403432  series  NaN        NaN        NaN
# 4378         36  tt2010510  series  NaN        NaN        NaN
#
# [12 rows x 23 columns]

# %% [markdown]
# When we look at the 'type' column, we notice all those missing are series, so we can exclude them since we are focusing on movies.

# %% [markdown]
# ## Genre Analysis

# %% [markdown]
# First, let's take a look at the genres of our data.
#
# We need to make sure there are no null values in our data for the genre column

# %%
dfGenre = dfCombined[~dfCombined.Genre.isnull()] #make a new dataframe with none of the titles that have genre as null.

# %%
dfGenre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4858 entries, 0 to 4868
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                4858 non-null   object
#  1   Year_x               4858 non-null   object
#  2   Rated                4597 non-null   object
#  3   Released             4789 non-null   object
#  4   Runtime              4808 non-null   object
#  5   Genre                4858 non-null   object
#  6   Director             4776 non-null   object
#  7   Writer               4691 non-null   object
#  8   Actors               4824 non-null   object
#  9   Plot                 4743 non-null   object
#  10  Language             4845 non-null   object
#  11  Country              4857 non-null   object
#  12  Awards               4145 non-null   object
#  13  Poster               4730 non-null   object
#  14  Ratings              4768 non-null   object
#  15  Metascore            4225 non-null   float64
#  16  imdbRating           4766 non-null   float64
#  17  imdbVotes            4766 non-null   object
#  18  imdbID               4858 non-null   object
#  19  Type                 4858 non-null   object
#  20  DVD                  4441 non-null   object
#  21  BoxOffice            4417 non-null   object
#  22  Production           4322 non-null   object
#  23  Year_y               4858 non-null   object
#  24  Worldwide R.O.I.(%)  4858 non-null   float64
# dtypes: float64(3), object(22)
# memory usage: 986.8+ KB

# %%
dfGenre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4359 entries, 0 to 4366
# Data columns (total 24 columns):
# title                  4359 non-null object
# year                   4359 non-null object
# Worldwide R.O.I.(%)    4359 non-null float64
# rated                  4184 non-null object
# released               4319 non-null object
# runtime                4329 non-null object
# genre                  4359 non-null object
# director               4311 non-null object
# writer                 4248 non-null object
# actors                 4335 non-null object
# plot                   4278 non-null object
# language               4346 non-null object
# country                4357 non-null object
# awards                 3780 non-null object
# poster                 4250 non-null object
# ratings                4359 non-null object
# metascore              3841 non-null float64
# imdb_rating            4294 non-null float64
# imdb_votes             4294 non-null object
# imdb_id                4359 non-null object
# type                   4359 non-null object
# dvd                    3827 non-null object
# box_office             2297 non-null object
# production             3825 non-null object
# dtypes: float64(3), object(21)
# memory usage: 851.4+ KB

# %% [markdown]
# From above we can see the number of Worldwide R.O.I.(%) values equals that of genres. Now we can see how many movies are classified with certain genres.

# %% [markdown]
# ### Violin Plot of R.O.I.

# %% [markdown]
# NOTE: we must first consider the Worldwide R.O.I. for all movies to know where 50% and more of the R.O.I. values lay for movies, so we can use it as a guide for looking at other R.O.I. values for all the subsequent comparisions.

# %%
sns.set(style="whitegrid", font_scale=2)
fig = plt.figure(figsize = (11,8))
plt.axes(ylim=[-5000, 5000])#pre set for better appearance

#fliers are also outliers of data[1]
#This violin plot gives out a look at frequency of the data points based on the width of the graph.
ax = sns.violinplot(y='Worldwide R.O.I.(%)', data=dfGenre, showfliers=True, orient='v', inner='quartile', bw=0.2)

#This finds the median of the data and labels it in white on the boxplot[]
median = round(df['Worldwide R.O.I.(%)'].median(),1) #rounds to the nearest first decimal place
xtick = ax.get_xticks() #gets tick location
vertical_offset = median * 0.05 #offsets slightly off of the median line
ax.text(xtick, median + vertical_offset, median, horizontalalignment='center', size='x-small',color='w',weight='semibold')

ax.set_title('Worldwide R.O.I. for Movies')

plt.show()

# %% [markdown]
# We should keep in mind that we are looking for a genre that gives us around the median value of 95.3% or up to the 800%.

# %% [markdown]
# Each movie title has either an individual or multiple genres associated with it. Therefore, we will only look at the top 40 genre combinations.

# %%
genres40 = dfGenre.Genre.value_counts().head(40)#This looks at the frequencies of the top 40 genres in the data
genres40
# Out:
# Comedy, Drama, Romance                           204
# Drama                                            196
# Comedy, Drama                                    181
# Comedy                                           179
# Comedy, Romance                                  153
# Drama, Romance                                   122
# Documentary                                       81
# Crime, Drama, Thriller                            78
# Action, Adventure, Sci-Fi                         71
# Action, Crime, Thriller                           68
# Action, Crime, Drama, Thriller                    67
# Crime, Drama, Mystery, Thriller                   62
# Horror, Mystery, Thriller                         59
# Action, Adventure, Thriller                       52
# Animation, Adventure, Comedy, Family, Fantasy     49
# Crime, Drama                                      48
# Horror, Thriller                                  45
# Action, Adventure, Sci-Fi, Thriller               45
# Documentary, Short                                44
# Comedy, Crime                                     43
# Drama, Thriller                                   43
# Action, Thriller                                  39
# Biography, Drama                                  38
# Biography, Drama, History                         34
# Action, Comedy, Crime                             33
# Drama, Mystery, Thriller                          31
# Biography, Drama, Sport                           30
# Action, Comedy, Crime, Thriller                   30
# Horror                                            30
# Action, Adventure, Fantasy                        28
# Horror, Mystery                                   27
# Action, Drama, Thriller                           24
# Drama, Music                                      23
# Action, Sci-Fi, Thriller                          23
# Comedy, Crime, Drama                              23
# Short                                             23
# Action, Adventure, Fantasy, Sci-Fi                22
# Drama, Music, Romance                             22
# Short, Drama                                      22
# Drama, Sport                                      20
# Name: Genre, dtype: int64

# %%
genres40 = dfGenre.genre.value_counts().head(40)#This looks at the frequencies of the top 40 genres in the data
genres40
# Out:
# Comedy, Drama, Romance                           178
# Comedy                                           159
# Drama                                            149
# Comedy, Drama                                    146
# Comedy, Romance                                  142
# Drama, Romance                                   107
# Action, Adventure, Sci-Fi                         68
# Horror, Mystery, Thriller                         65
# Crime, Drama, Thriller                            63
# Action, Crime, Drama, Thriller                    60
# Horror, Thriller                                  59
# Action, Crime, Thriller                           59
# Crime, Drama, Mystery, Thriller                   58
# Documentary                                       52
# Action, Adventure, Thriller                       51
# Drama, Thriller                                   43
# Comedy, Crime                                     43
# Action, Adventure, Sci-Fi, Thriller               42
# Crime, Drama                                      40
# Horror                                            39
# Animation, Adventure, Comedy, Family, Fantasy     39
# Action, Thriller                                  36
# Biography, Drama                                  35
# Documentary, Short                                33
# Biography, Drama, History                         30
# Biography, Drama, Sport                           29
# Action, Adventure, Fantasy                        29
# Action, Comedy, Crime                             28
# Action, Drama, Thriller                           26
# Drama, Mystery, Thriller                          26
# Action, Comedy, Crime, Thriller                   26
# Drama, Music, Romance                             23
# Drama, Sport                                      22
# Action, Sci-Fi                                    21
# Action, Sci-Fi, Thriller                          21
# Comedy, Family                                    21
# Comedy, Crime, Drama                              20
# Animation, Adventure, Comedy, Family              20
# Horror, Mystery                                   19
# Action, Crime, Drama, Mystery, Thriller           17
# Name: genre, dtype: int64

# %%
genrelist = list(genres40.keys())#converts the top 40 genres to a list
genrelist
# Out:
# ['Comedy, Drama, Romance',
#  'Drama',
#  'Comedy, Drama',
#  'Comedy',
#  'Comedy, Romance',
#  'Drama, Romance',
#  'Documentary',
#  'Crime, Drama, Thriller',
#  'Action, Adventure, Sci-Fi',
#  'Action, Crime, Thriller',
#  'Action, Crime, Drama, Thriller',
#  'Crime, Drama, Mystery, Thriller',
#  'Horror, Mystery, Thriller',
#  'Action, Adventure, Thriller',
#  'Animation, Adventure, Comedy, Family, Fantasy',
#  'Crime, Drama',
#  'Horror, Thriller',
#  'Action, Adventure, Sci-Fi, Thriller',
#  'Documentary, Short',
#  'Comedy, Crime',
#  'Drama, Thriller',
#  'Action, Thriller',
#  'Biography, Drama',
#  'Biography, Drama, History',
#  'Action, Comedy, Crime',
#  'Drama, Mystery, Thriller',
#  'Biography, Drama, Sport',
#  'Action, Comedy, Crime, Thriller',
#  'Horror',
#  'Action, Adventure, Fantasy',
#  'Horror, Mystery',
#  'Action, Drama, Thriller',
#  'Drama, Music',
#  'Action, Sci-Fi, Thriller',
#  'Comedy, Crime, Drama',
#  'Short',
#  'Action, Adventure, Fantasy, Sci-Fi',
#  'Drama, Music, Romance',
#  'Short, Drama',
#  'Drama, Sport']

# %% [markdown]
# ### Bar Graph of Movie Genre Variations

# %% [markdown]
# We plot a bar graph of these top 40 genre combinations to see which have the most number of movies. [2]

# %%
sns.set(style="whitegrid", font_scale=3)
fig = plt.figure(figsize = (30,30))
ax = sns.countplot(y='Genre', data=dfGenre, order=genrelist) #order= organizes your data by a given list
ax.set_title('Movie Genres')
plt.xlabel('Number of Movies')
plt.ylabel('Genre')

plt.show()

# %% [markdown]
# ### Box Plots of Movie Genre Variations

# %% [markdown]
# With these top 40 genres, we also look at their R.O.I.'s with box plots. [3]

# %%
sns.set(style="whitegrid", font_scale=3)
fig = plt.figure(figsize = (30,30))
ax = sns.boxplot(y='Genre', x='Worldwide R.O.I.(%)', data=dfGenre, fliersize=10
            , showfliers=False, order=genrelist) #order= organizes your data by a given list
ax.set_title('Movie Genres')
plt.xlabel('Worldwide R.O.I.(%)')
plt.ylabel('Genre')

plt.show()

# %% [markdown]
# In the boxplot below, we limit the R.O.I. range to (95, 800) since we need to keep in mind the aforementioned R.O.I. of 95.3%.

# %%
sns.set(style="whitegrid", font_scale=3)
fig = plt.figure(figsize = (30,30))
ax = sns.boxplot(y='Genre', x='Worldwide R.O.I.(%)', data=dfGenre, fliersize=10
            , showfliers=False, order=genrelist) #order= organizes your data by a given list
ax.set_title('Movie Genres')
ax.set_xlim(95, 800)
plt.xlabel('Worldwide R.O.I.(%)')
plt.ylabel('Genre')

plt.show()

# %% [markdown]
# From the above boxplot, we notice that movies do not appear to be constrained to only 1 genre. Another observation is that there are a lot of repeated genres. The some common genres that have a median value or 50% of the movies above 95.3% R.O.I. are Horror, Action, Adventure, and Thriller.
#
# Next we will take a look at Maturity Rating.

# %% [markdown]
# ## Maturity Rating Analysis

# %% [markdown]
# Let's look at our combined data again.

# %%
dfCombined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4869 entries, 0 to 4868
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                4869 non-null   object
#  1   Year_x               4869 non-null   object
#  2   Rated                4600 non-null   object
#  3   Released             4797 non-null   object
#  4   Runtime              4814 non-null   object
#  5   Genre                4858 non-null   object
#  6   Director             4782 non-null   object
#  7   Writer               4696 non-null   object
#  8   Actors               4833 non-null   object
#  9   Plot                 4747 non-null   object
#  10  Language             4853 non-null   object
#  11  Country              4866 non-null   object
#  12  Awards               4145 non-null   object
#  13  Poster               4735 non-null   object
#  14  Ratings              4775 non-null   object
#  15  Metascore            4225 non-null   float64
#  16  imdbRating           4773 non-null   float64
#  17  imdbVotes            4773 non-null   object
#  18  imdbID               4869 non-null   object
#  19  Type                 4869 non-null   object
#  20  DVD                  4442 non-null   object
#  21  BoxOffice            4417 non-null   object
#  22  Production           4322 non-null   object
#  23  Year_y               4869 non-null   object
#  24  Worldwide R.O.I.(%)  4869 non-null   float64
# dtypes: float64(3), object(22)
# memory usage: 989.0+ KB

# %% [markdown]
# We notice that 'rated' has 4185 objects and 'Worldwide R.O.I.(%)' has 4367 float64, so these need to match before we plot. Let's find any null values.

# %%
dfRated = dfCombined[~dfCombined.Rated.isnull()]#Check which movies have null in their 'rated' column

# %%
dfRated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4600 entries, 0 to 4868
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                4600 non-null   object
#  1   Year_x               4600 non-null   object
#  2   Rated                4600 non-null   object
#  3   Released             4587 non-null   object
#  4   Runtime              4598 non-null   object
#  5   Genre                4597 non-null   object
#  6   Director             4582 non-null   object
#  7   Writer               4554 non-null   object
#  8   Actors               4595 non-null   object
#  9   Plot                 4594 non-null   object
#  10  Language             4595 non-null   object
#  11  Country              4598 non-null   object
#  12  Awards               4107 non-null   object
#  13  Poster               4591 non-null   object
#  14  Ratings              4596 non-null   object
#  15  Metascore            4215 non-null   float64
#  16  imdbRating           4596 non-null   float64
#  17  imdbVotes            4596 non-null   object
#  18  imdbID               4600 non-null   object
#  19  Type                 4600 non-null   object
#  20  DVD                  4414 non-null   object
#  21  BoxOffice            4400 non-null   object
#  22  Production           4298 non-null   object
#  23  Year_y               4600 non-null   object
#  24  Worldwide R.O.I.(%)  4600 non-null   float64
# dtypes: float64(3), object(22)
# memory usage: 934.4+ KB

# %% [markdown]
# Now we see that the 'rated' and 'Worldwide R.O.I.(%)' match. Let's take a quick look at what ratings the movies have.

# %%
mrating = dfRated.Rated.value_counts()#This looks at the rating frequencies in the data
mrating
# Out:
# R            1983
# PG-13        1522
# PG            704
# Not Rated     156
# G             116
# Approved       32
# Unrated        24
# Passed         23
# NC-17           8
# TV-14           7
# TV-PG           6
# TV-MA           5
# X               4
# M               2
# TV-G            2
# GP              2
# M/PG            2
# NOT RATED       1
# UNRATED         1
# Name: Rated, dtype: int64

# %% [markdown]
# We see that there are ratings that could fit into 'Not Rated', so let's makes those movies go into that category.[4]

# %%
dfRated[dfRated.Rated == 'Unrated'].Rated #This reveals at which index a movie is rated 'Not Rated'
# Out:
# 960     Unrated
# 2551    Unrated
# 3565    Unrated
# 3665    Unrated
# 3749    Unrated
# 3870    Unrated
# 4024    Unrated
# 4031    Unrated
# 4041    Unrated
# 4137    Unrated
# 4202    Unrated
# 4221    Unrated
# 4245    Unrated
# 4287    Unrated
# 4301    Unrated
# 4311    Unrated
# 4340    Unrated
# 4541    Unrated
# 4548    Unrated
# 4770    Unrated
# 4776    Unrated
# 4779    Unrated
# 4810    Unrated
# 4818    Unrated
# Name: Rated, dtype: object

# %%
list1 = list(dfRated[dfRated.Rated == 'Unrated'].Rated.keys()) #makes a list of the index values

# %%
list1 = list(dfRated[dfRated.rated == 'Unrated'].rated.keys()) #makes a list of the index values

# %%
dfnewupdate = pd.DataFrame({'rated':'Not Rated' }, index=list1) #makes new df for updating our current dataframe.

# %%
dfRated.update(dfnewupdate) #update dataframe [4]
# Out:
# C:\Users\johnh\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:5804: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = expressions.where(mask, this, that)

# %%
list1 = list(dfRated[dfRated.rated == 'UNRATED'].rated.keys()) #makes a list of the index values

# %%
dfnewupdate = pd.DataFrame({'rated':'Not Rated' }, index=list1)

# %%
dfRated.update(dfnewupdate)

# %%
list1 = list(dfRated[dfRated.rated == 'NOT RATED'].rated.keys()) #makes a list of the index values

# %%
dfnewupdate = pd.DataFrame({'rated':'Not Rated' }, index=list1)

# %%
dfRated.update(dfnewupdate)

# %%
mrating = dfRated.rated.value_counts()#This looks at the rating frequencies in the data #checks to see if everything worked.
mrating
# Out:
# R            1766
# PG-13        1429
# PG            677
# Not Rated     130
# G             118
# Approved       22
# Passed         21
# NC-17           5
# X               4
# TV-PG           3
# GP              3
# TV-14           2
# M               2
# M/PG            1
# TV-MA           1
# PASSED          1
# Name: rated, dtype: int64

# %% [markdown]
# ### Bar Graph, Box Plot, and Violin Plot of Maturity Rating Vs. Worldwide R.O.I. and Number of Movies

# %% [markdown]
# Let's plot to see how many movies have certain ratings and how much R.O.I. each rating has.

# %%
sns.set(style="whitegrid", font_scale=1.5)
fig, axes = plt.subplots(3,1, figsize = (15, 22))
fig.suptitle('Maturity Rating Vs. Worldwide R.O.I. and Number of Movies')

ax0 = axes[0]
ax0.set_title('Movie Maturity Rating')
sns.countplot(x='rated', data=dfRated, order=['G', 'PG', 'PG-13', 'R', 'Not Rated', 'NC-17'], ax=ax0)
ax0.set_ylabel('Number of Movies')
ax0.set_xlabel('Maturity Rating')



ax1 = axes[1]
ax1.set_title('Worldwide R.O.I. by Maturity Rating')

sns.boxplot(x='rated', y='Worldwide R.O.I.(%)', data=dfRated, fliersize=10
            , showfliers=False, order=['G', 'PG', 'PG-13', 'R', 'Not Rated', 'NC-17'], ax=ax1)
ax1.set_xlabel('Maturity Rating')



ax2 = axes[2]
ax2.set_ylim(-150, 1200)
ax2.set_title('Worldwide R.O.I. by Maturity Rating')

sns.violinplot(x='rated', y='Worldwide R.O.I.(%)', data=dfRated, fliersize=10
            , showfliers=False, order=['G', 'PG', 'PG-13', 'R', 'Not Rated', 'NC-17'], ax=ax2, bw=0.2)
ax2.set_xlabel('Maturity Rating')




plt.show()

# %% [markdown]
# From the above graphs, we can see that 'G' and 'PG' have the highest median values out of all the movie related ratings. In addition, ~75% of the movies made are above 0% R.O.I.

# %% [markdown]
# ## Genre Analysis with Selected Maturity Ratings

# %% [markdown]
# We will plot the genres that have the most amount of movies which are 'PG-13' and 'R'

# %%
#This gets a list of the top 21 occuring genres for the two ratings.
ratGenre21 = list(dfRated[(dfRated.rated == 'PG-13') | (dfRated.rated == 'R') ].genre.value_counts().head(21).keys())
ratGenre21
# Out:
# ['Comedy, Drama, Romance',
#  'Comedy',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Drama',
#  'Drama, Romance',
#  'Horror, Mystery, Thriller',
#  'Crime, Drama, Thriller',
#  'Action, Adventure, Sci-Fi',
#  'Action, Crime, Drama, Thriller',
#  'Action, Crime, Thriller',
#  'Horror, Thriller',
#  'Crime, Drama, Mystery, Thriller',
#  'Drama, Thriller',
#  'Comedy, Crime',
#  'Action, Adventure, Sci-Fi, Thriller',
#  'Crime, Drama',
#  'Action, Adventure, Thriller',
#  'Action, Thriller',
#  'Biography, Drama',
#  'Horror']

# %% [markdown]
# ### Bar Graph of Movie Genre with Selected Maturity Rating

# %%
sns.set(style="whitegrid", font_scale=2)
fig = plt.figure(figsize = (15,30))
ax = sns.countplot(y='genre', data=dfRated, order=ratGenre21, hue='rated', hue_order=['PG-13', 'R']) #order= organizes your data by a given list
ax.set_title('Movie Genre and Maturity Rating')
plt.xlabel('Number of Movies')
plt.ylabel('Genre')

plt.show()

# %% [markdown]
#  ### Box Plot of Movie Genre with Selected Maturity Rating

# %%
sns.set(style="whitegrid", font_scale=2)
fig = plt.figure(figsize = (15,30))
ax = sns.boxplot(y='genre', x='Worldwide R.O.I.(%)', data=dfRated, order=ratGenre21, hue='rated', hue_order=['PG-13', 'R']
                 , fliersize=10, showfliers=False) #order= organizes your data by a given list
ax.set_title('Movie Genre/Rating and Worldwide R.O.I.')
plt.xlabel('Worldwide R.O.I.(%)')
plt.ylabel('Genre')
ax.set_xlim(-100, 1200)
plt.show()

# %% [markdown]
# From the two above plots, we can recommend a PG-13 or R movie with Horror or Action/Adventure

# %% [markdown]
# ## Resources used for development:
# 1. https://seaborn.pydata.org/generated/seaborn.violinplot.html#seaborn.violinplot
# 2. https://seaborn.pydata.org/generated/seaborn.countplot.html
# 3. https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot
# 4. https://en.wikipedia.org/wiki/Motion_Picture_Association_of_America_film_rating_system
# 5. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.update.html
